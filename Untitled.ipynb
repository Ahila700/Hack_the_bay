# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('CBP_water_dictionary_final.csv', index_col = 0)

# %%
df
# Out:
#                                                    CBP Parameter CBP Unit  \
# CBP Code
# ATEMP                                        AIR TEMPERATURE DEG        C
# CHLA                                        ACTIVE CHLOROPHYLL-A     UG/L
# DO                                      DISSOLVED OXYGEN IN MG/L     MG/L
# DO_SAT_P              DO SATURATION USING PROBE UNITS IN PERCENT      PCT
# NH4F                    AMMONIUM NITROGEN AS N (FILTERED SAMPLE)     MG/L
# NO3F                     NITRATE NITROGEN AS N (FILTERED SAMPLE)     MG/L
# PH                       PH CORRECTED FOR TEMPERATURE (25 DEG C)       SU
# PO4F            ORTHOPHOSPHATE PHOSPHORUS AS P (FILTERED SAMPLE)     MG/L
# SALINITY       SALINITY UNITS IN PPT AND EQUAL TO PRACTICAL S...      PPT
# SECCHI                                              SECCHI DEPTH        M
# TALK                                   TOTAL ALKALINITY AS CACO3     MG/L
# ...

# %%
df2 = pd.read_csv('problemCodes.csv', index_col = 0)

# %%
df2
# Out:
#    Code                                        Description  Order  \
# Id
# 1     A                                Laboratory Accident      9
# 2     V         Sample results rejected due to QC criteria      4
# 4     B                       Chemical Matrix Interference     11
# 5    BB                                    Torn Filter Pad     12
# 6     C                                 Instrument Failure      1
# 7     D                                Insufficient Sample     13
# 8    DD                           Sample Size Not Reported     14
# 9     E                 Sample Received After Holding Time      7
# 10   FF       Poor Replication Between Pads, Mean reported     15
# 11   GG                 Sample Analyzed After Holding Time      8
# 12    I            Suspect Value Has Been Verified Correct     16
# 13    J             Incorrect Sample Fraction For Analysis     17
# 14   JJ             Volume Filtered Not Recorded (assumed)     18
# ...

# %%
df3 = pd.read_csv('qualifierCodes.csv', index_col = 0)

# %%
df3
# Out:
#                                             Description
# Code
# <      Less than the lower method detection limit (MDL)
# >     Greater than the upper method detection limit ...
# E                                       Estimated Value
